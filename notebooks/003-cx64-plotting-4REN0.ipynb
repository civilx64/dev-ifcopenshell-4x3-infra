# %% [markdown]
# # 003 Plotting - 4REN0
#
# Develop plots for visually checking a recognizable alignment from a
# previous design project

# %%
import os

import ifcopenshell
import ifcopenshell.geom
from ifcopenshell.ifcgeom import Alignment


geometry = True

file_path = os.path.join(
    "..",
    "tests",
    "data",
)

test_file = "4REN0_Autodesk.ifc"
in_file = os.path.join(file_path, test_file)

model = ifcopenshell.open(in_file)

ent = model.by_type("IfcAlignment")[0]

align = Alignment().from_entity(ent)
align.plot(title=test_file, interactive=True)
